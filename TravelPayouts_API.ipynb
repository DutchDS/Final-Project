# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser

import requests 
import pymongo
import pandas as pd
import re
import os
import csv
import json
import pprint
from datetime import datetime, timedelta

# %%
direct_flights_url = "http://api.travelpayouts.com/v2/prices/latest?currency=usd&period_type=year&page=1&limit=300&show_to_affiliates=true&sorting=price&trip_class=0&token=86f1c7cb27aacf8deedaef90c568e73d"

# %%
# Create an empty list to store the responses
response_json = []

# %%
response = requests.get(direct_flights_url)

# %%
if response.status_code == 200:
        response = response.json()
        response_json.append(response)

# %%
pprint.pprint(response_json)
# Out:
# [{'data': [{'actual': True,
#             'depart_date': '2020-03-23',
#             'destination': 'LGK',
#             'distance': 130,
#             'duration': 80,
#             'found_at': '2020-02-10T08:20:04.206070',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'PEN',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 5.38},
#            {'actual': True,
#             'depart_date': '2020-02-14',
#             'destination': 'STO',
#             'distance': 498,
#             'duration': 150,
#             'found_at': '2020-02-13T19:14:37.704304',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-02-18',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 9.94},
#            {'actual': True,
#             'depart_date': '2020-02-28',
#             'destination': 'BTS',
#             'distance': 647,
#             'duration': 155,
#             'found_at': '2020-02-13T23:00:10.775230',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'INI',
#             'return_date': '2020-03-02',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.12},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'LON',
#             'distance': 431,
#             'duration': 160,
#             'found_at': '2020-02-13T18:47:15.607827',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DUB',
#             'return_date': '2020-03-03',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.13},
#            {'actual': True,
#             'depart_date': '2020-02-19',
#             'destination': 'BKI',
#             'distance': 274,
#             'duration': 115,
#             'found_at': '2020-02-10T13:47:09.894735',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'TWU',
#             'return_date': '2020-02-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.26},
#            {'actual': True,
#             'depart_date': '2020-03-12',
#             'destination': 'LON',
#             'distance': 488,
#             'duration': 160,
#             'found_at': '2020-02-11T19:50:28.824723',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'CGN',
#             'return_date': '2020-03-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.31},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'VIE',
#             'distance': 547,
#             'duration': 150,
#             'found_at': '2020-02-11T14:25:18.974116',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'STR',
#             'return_date': '2020-03-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.31},
#            {'actual': True,
#             'depart_date': '2020-02-25',
#             'destination': 'GDN',
#             'distance': 498,
#             'duration': 150,
#             'found_at': '2020-02-13T04:48:48.785436',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'STO',
#             'return_date': '2020-02-29',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 11.45},
#            {'actual': True,
#             'depart_date': '2020-04-10',
#             'destination': 'KUL',
#             'distance': 409,
#             'duration': 145,
#             'found_at': '2020-02-10T11:30:28.924817',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'AOR',
#             'return_date': '2020-04-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 12.28},
#            {'actual': True,
#             'depart_date': '2020-04-14',
#             'destination': 'AOR',
#             'distance': 409,
#             'duration': 135,
#             'found_at': '2020-02-11T02:37:24.731069',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-04-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 12.99},
#            {'actual': True,
#             'depart_date': '2020-09-18',
#             'destination': 'CWB',
#             'distance': 533,
#             'duration': 930,
#             'found_at': '2020-02-10T03:42:10.682175',
#             'gate': 'MyHolidays',
#             'number_of_changes': 2,
#             'origin': 'POA',
#             'return_date': '2020-09-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 13.13},
#            {'actual': True,
#             'depart_date': '2020-03-11',
#             'destination': 'DUB',
#             'distance': 470,
#             'duration': 165,
#             'found_at': '2020-02-13T14:53:27.251871',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'LON',
#             'return_date': '2020-03-11',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 13.24},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'DUB',
#             'distance': 321,
#             'duration': 140,
#             'found_at': '2020-02-13T23:56:35.274669',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BHX',
#             'return_date': '2020-03-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 13.24},
#            {'actual': True,
#             'depart_date': '2020-05-03',
#             'destination': 'TGG',
#             'distance': 330,
#             'duration': 125,
#             'found_at': '2020-02-10T03:34:34.017828',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-05-06',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 14.45},
#            {'actual': True,
#             'depart_date': '2020-03-05',
#             'destination': 'JHB',
#             'distance': 251,
#             'duration': 105,
#             'found_at': '2020-02-12T09:08:59.221306',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-03-09',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 14.74},
#            {'actual': True,
#             'depart_date': '2020-02-28',
#             'destination': 'STO',
#             'distance': 741,
#             'duration': 185,
#             'found_at': '2020-02-13T23:20:45.032490',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-03-01',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 15.18},
#            {'actual': True,
#             'depart_date': '2020-03-16',
#             'destination': 'RIO',
#             'distance': 373,
#             'duration': 445,
#             'found_at': '2020-02-11T00:17:43.641582',
#             'gate': 'Biletix',
#             'number_of_changes': 1,
#             'origin': 'BHZ',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 15.24},
#            {'actual': True,
#             'depart_date': '2020-03-30',
#             'destination': 'STR',
#             'distance': 547,
#             'duration': 150,
#             'found_at': '2020-02-10T15:32:39.346904',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'VIE',
#             'return_date': '2020-04-05',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 15.48},
#            {'actual': True,
#             'depart_date': '2020-03-20',
#             'destination': 'BHZ',
#             'distance': 361,
#             'duration': 690,
#             'found_at': '2020-02-13T03:18:55.319126',
#             'gate': 'Biletix',
#             'number_of_changes': 1,
#             'origin': 'RIO',
#             'return_date': '2020-03-23',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 15.64},
#            {'actual': True,
#             'depart_date': '2020-02-19',
#             'destination': 'MOW',
#             'distance': 697,
#             'duration': 200,
#             'found_at': '2020-02-13T05:40:56.382066',
#             'gate': 'Pobeda',
#             'number_of_changes': 0,
#             'origin': 'PES',
#             'return_date': '2020-02-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 15.83},
#            {'actual': True,
#             'depart_date': '2020-03-04',
#             'destination': 'VIE',
#             'distance': 588,
#             'duration': 560,
#             'found_at': '2020-02-12T04:19:33.775428',
#             'gate': 'City.Travel',
#             'number_of_changes': 1,
#             'origin': 'MIL',
#             'return_date': '2020-03-05',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 16.26},
#            {'actual': True,
#             'depart_date': '2020-05-08',
#             'destination': 'LSC',
#             'distance': 388,
#             'duration': 119,
#             'found_at': '2020-02-13T17:02:30.547836',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'SCL',
#             'return_date': '2020-05-12',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 16.37},
#            {'actual': True,
#             'depart_date': '2020-04-16',
#             'destination': 'KUL',
#             'distance': 251,
#             'duration': 115,
#             'found_at': '2020-02-12T15:36:12.978637',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'JHB',
#             'return_date': '2020-07-15',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 16.69},
#            {'actual': True,
#             'depart_date': '2020-03-27',
#             'destination': 'INI',
#             'distance': 647,
#             'duration': 155,
#             'found_at': '2020-02-11T09:44:55.936320',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BTS',
#             'return_date': '2020-04-03',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 16.92},
#            {'actual': True,
#             'depart_date': '2020-02-25',
#             'destination': 'VOG',
#             'distance': 390,
#             'duration': 175,
#             'found_at': '2020-02-11T16:02:39.178657',
#             'gate': 'Utair',
#             'number_of_changes': 0,
#             'origin': 'ASF',
#             'return_date': '2020-02-28',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 17.16},
#            {'actual': True,
#             'depart_date': '2020-05-01',
#             'destination': 'ASF',
#             'distance': 390,
#             'duration': 155,
#             'found_at': '2020-02-13T14:16:24.806315',
#             'gate': 'Utair',
#             'number_of_changes': 0,
#             'origin': 'VOG',
#             'return_date': '2020-05-05',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 17.16},
#            {'actual': True,
#             'depart_date': '2020-04-27',
#             'destination': 'LGK',
#             'distance': 454,
#             'duration': 135,
#             'found_at': '2020-02-11T10:21:41.653425',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-05-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 17.29},
#            {'actual': True,
#             'depart_date': '2020-04-28',
#             'destination': 'BSB',
#             'distance': 928,
#             'duration': 535,
#             'found_at': '2020-02-13T10:49:54.416862',
#             'gate': 'Biletix',
#             'number_of_changes': 1,
#             'origin': 'RIO',
#             'return_date': '2020-05-08',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 18.59},
#            {'actual': True,
#             'depart_date': '2020-04-17',
#             'destination': 'VIE',
#             'distance': 456,
#             'duration': 150,
#             'found_at': '2020-02-12T10:42:37.276876',
#             'gate': 'Clickavia',
#             'number_of_changes': 0,
#             'origin': 'ZAD',
#             'return_date': '2020-04-20',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 18.89},
#            {'actual': True,
#             'depart_date': '2020-02-25',
#             'destination': 'BLL',
#             'distance': 612,
#             'duration': 155,
#             'found_at': '2020-02-13T20:19:38.766656',
#             'gate': 'Wizz Air',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-03-10',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 19.62},
#            {'actual': True,
#             'depart_date': '2020-03-29',
#             'destination': 'DUB',
#             'distance': 306,
#             'duration': 125,
#             'found_at': '2020-02-12T18:25:25.365486',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'LBA',
#             'return_date': '2020-04-01',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.02},
#            {'actual': True,
#             'depart_date': '2020-05-06',
#             'destination': 'KBR',
#             'distance': 385,
#             'duration': 140,
#             'found_at': '2020-02-12T20:41:31.665419',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-05-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.03},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'OSL',
#             'distance': 730,
#             'duration': 180,
#             'found_at': '2020-02-12T17:54:08.197904',
#             'gate': 'Wizz Air',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-03-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.05},
#            {'actual': True,
#             'depart_date': '2020-03-27',
#             'destination': 'KUL',
#             'distance': 324,
#             'duration': 125,
#             'found_at': '2020-02-10T03:00:56.660927',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'PEN',
#             'return_date': '2020-04-10',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.11},
#            {'actual': True,
#             'depart_date': '2020-02-16',
#             'destination': 'MNL',
#             'distance': 567,
#             'duration': 170,
#             'found_at': '2020-02-10T05:58:30.761138',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'CEB',
#             'return_date': '2020-02-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.37},
#            {'actual': True,
#             'depart_date': '2020-04-09',
#             'destination': 'PEN',
#             'distance': 324,
#             'duration': 120,
#             'found_at': '2020-02-10T08:34:27.873938',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUL',
#             'return_date': '2020-04-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.37},
#            {'actual': True,
#             'depart_date': '2020-03-20',
#             'destination': 'OSL',
#             'distance': 1181,
#             'duration': 250,
#             'found_at': '2020-02-13T18:45:35.648810',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KRK',
#             'return_date': '2020-03-23',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.4},
#            {'actual': True,
#             'depart_date': '2020-06-09',
#             'destination': 'BRU',
#             'distance': 1141,
#             'duration': 240,
#             'found_at': '2020-02-13T21:55:49.231226',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-06-18',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.4},
#            {'actual': True,
#             'depart_date': '2020-02-22',
#             'destination': 'ODS',
#             'distance': 1232,
#             'duration': 260,
#             'found_at': '2020-02-13T18:12:34.647464',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-02-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-03-05',
#             'destination': 'BRU',
#             'distance': 877,
#             'duration': 210,
#             'found_at': '2020-02-13T19:36:10.259826',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WRO',
#             'return_date': '2020-03-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-02-21',
#             'destination': 'GOT',
#             'distance': 785,
#             'duration': 180,
#             'found_at': '2020-02-13T18:15:07.782326',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-02-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-02-19',
#             'destination': 'KHE',
#             'distance': 1080,
#             'duration': 235,
#             'found_at': '2020-02-13T17:40:45.142442',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KTW',
#             'return_date': '2020-02-23',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-03-20',
#             'destination': 'OSL',
#             'distance': 988,
#             'duration': 220,
#             'found_at': '2020-02-13T22:28:26.434648',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-03-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-03-30',
#             'destination': 'CGN',
#             'distance': 947,
#             'duration': 215,
#             'found_at': '2020-02-13T22:31:18.301465',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-03-31',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.41},
#            {'actual': True,
#             'depart_date': '2020-03-21',
#             'destination': 'KHE',
#             'distance': 1018,
#             'duration': 230,
#             'found_at': '2020-02-11T18:27:24.140511',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KRK',
#             'return_date': '2020-03-28',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.64},
#            {'actual': True,
#             'depart_date': '2020-03-18',
#             'destination': 'ODS',
#             'distance': 1198,
#             'duration': 260,
#             'found_at': '2020-02-10T20:00:05.459467',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'POZ',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.64},
#            {'actual': True,
#             'depart_date': '2020-04-08',
#             'destination': 'KUL',
#             'distance': 202,
#             'duration': 105,
#             'found_at': '2020-02-12T05:00:46.366039',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KUA',
#             'return_date': '2020-04-30',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.64},
#            {'actual': True,
#             'depart_date': '2020-03-07',
#             'destination': 'BER',
#             'distance': 528,
#             'duration': 150,
#             'found_at': '2020-02-11T19:17:19.878652',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KRK',
#             'return_date': '2020-03-10',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.64},
#            {'actual': True,
#             'depart_date': '2020-02-20',
#             'destination': 'ODS',
#             'distance': 964,
#             'duration': 220,
#             'found_at': '2020-02-12T13:19:53.053908',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KTW',
#             'return_date': '2020-02-22',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.65},
#            {'actual': True,
#             'depart_date': '2020-03-12',
#             'destination': 'AAR',
#             'distance': 539,
#             'duration': 145,
#             'found_at': '2020-02-12T19:40:27.405853',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-03-15',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.65},
#            {'actual': True,
#             'depart_date': '2020-03-10',
#             'destination': 'MIL',
#             'distance': 911,
#             'duration': 210,
#             'found_at': '2020-02-12T09:15:52.065104',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'POZ',
#             'return_date': '2020-03-17',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.65},
#            {'actual': True,
#             'depart_date': '2020-02-27',
#             'destination': 'EVN',
#             'distance': 82,
#             'duration': 315,
#             'found_at': '2020-02-13T05:43:53.943016',
#             'gate': 'City.Travel',
#             'number_of_changes': 0,
#             'origin': 'LWN',
#             'return_date': '2020-03-12',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.68},
#            {'actual': True,
#             'depart_date': '2020-02-14',
#             'destination': 'LWN',
#             'distance': 82,
#             'duration': 315,
#             'found_at': '2020-02-13T22:27:21.311466',
#             'gate': 'City.Travel',
#             'number_of_changes': 0,
#             'origin': 'EVN',
#             'return_date': '2020-02-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.75},
#            {'actual': True,
#             'depart_date': '2020-04-17',
#             'destination': 'ZAD',
#             'distance': 456,
#             'duration': 150,
#             'found_at': '2020-02-12T09:12:42.229683',
#             'gate': 'Kiwi.com',
#             'number_of_changes': 0,
#             'origin': 'VIE',
#             'return_date': '2020-04-20',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.76},
#            {'actual': True,
#             'depart_date': '2020-03-25',
#             'destination': 'EIN',
#             'distance': 1049,
#             'duration': 230,
#             'found_at': '2020-02-13T22:12:32.564222',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'WAW',
#             'return_date': '2020-04-01',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.81},
#            {'actual': True,
#             'depart_date': '2020-02-27',
#             'destination': 'MNL',
#             'distance': 453,
#             'duration': 155,
#             'found_at': '2020-02-13T01:06:12.160790',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'ILO',
#             'return_date': '2020-03-01',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.92},
#            {'actual': True,
#             'depart_date': '2020-03-24',
#             'destination': 'KTW',
#             'distance': 934,
#             'duration': 210,
#             'found_at': '2020-02-12T12:44:15.009840',
#             'gate': 'Wizz Air',
#             'number_of_changes': 0,
#             'origin': 'STO',
#             'return_date': '2020-03-28',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.97},
#            {'actual': True,
#             'depart_date': '2020-02-20',
#             'destination': 'DNZ',
#             'distance': 348,
#             'duration': 125,
#             'found_at': '2020-02-12T22:46:40.371068',
#             'gate': 'Pegasus Airlines',
#             'number_of_changes': 0,
#             'origin': 'IST',
#             'return_date': '2020-02-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 20.98},
#            {'actual': True,
#             'depart_date': '2020-03-21',
#             'destination': 'WAW',
#             'distance': 1161,
#             'duration': 250,
#             'found_at': '2020-02-12T03:10:37.748614',
#             'gate': 'FlightNetwork',
#             'number_of_changes': 0,
#             'origin': 'BRU',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.03},
#            {'actual': True,
#             'depart_date': '2020-03-12',
#             'destination': 'OSL',
#             'distance': 1118,
#             'duration': 235,
#             'found_at': '2020-02-13T16:10:53.744833',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KTW',
#             'return_date': '2020-03-15',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.29},
#            {'actual': True,
#             'depart_date': '2020-03-16',
#             'destination': 'VIE',
#             'distance': 671,
#             'duration': 170,
#             'found_at': '2020-02-12T19:15:47.539772',
#             'gate': 'FlightNetwork',
#             'number_of_changes': 0,
#             'origin': 'INI',
#             'return_date': '2020-03-20',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.33},
#            {'actual': True,
#             'depart_date': '2020-03-06',
#             'destination': 'HAU',
#             'distance': 973,
#             'duration': 215,
#             'found_at': '2020-02-13T16:07:55.230303',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-03-09',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.41},
#            {'actual': True,
#             'depart_date': '2020-03-23',
#             'destination': 'MIL',
#             'distance': 1141,
#             'duration': 245,
#             'found_at': '2020-02-13T05:16:17.542662',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'SOF',
#             'return_date': '2020-03-26',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.43},
#            {'actual': True,
#             'depart_date': '2020-03-24',
#             'destination': 'EDI',
#             'distance': 335,
#             'duration': 130,
#             'found_at': '2020-02-11T15:47:39.679795',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DUB',
#             'return_date': '2020-03-26',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.46},
#            {'actual': True,
#             'depart_date': '2020-05-26',
#             'destination': 'IGU',
#             'distance': 1180,
#             'duration': 670,
#             'found_at': '2020-02-12T07:22:46.469322',
#             'gate': 'Biletix.kz',
#             'number_of_changes': 2,
#             'origin': 'RIO',
#             'return_date': '2020-05-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.49},
#            {'actual': True,
#             'depart_date': '2020-04-01',
#             'destination': 'BUD',
#             'distance': 685,
#             'duration': 180,
#             'found_at': '2020-02-12T14:37:00.812872',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'BER',
#             'return_date': '2020-04-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.57},
#            {'actual': True,
#             'depart_date': '2020-03-02',
#             'destination': 'BUD',
#             'distance': 1130,
#             'duration': 240,
#             'found_at': '2020-02-13T21:28:32.411906',
#             'gate': 'FlightNetwork',
#             'number_of_changes': 0,
#             'origin': 'BRU',
#             'return_date': '2020-03-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.6},
#            {'actual': True,
#             'depart_date': '2020-03-13',
#             'destination': 'MIL',
#             'distance': 1013,
#             'duration': 225,
#             'found_at': '2020-02-12T04:51:19.265659',
#             'gate': 'Wizz Air',
#             'number_of_changes': 0,
#             'origin': 'DEB',
#             'return_date': '2020-03-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.65},
#            {'actual': True,
#             'depart_date': '2020-02-27',
#             'destination': 'VIE',
#             'distance': 775,
#             'duration': 205,
#             'found_at': '2020-02-12T10:30:15.383904',
#             'gate': 'FlightNetwork',
#             'number_of_changes': 0,
#             'origin': 'BRE',
#             'return_date': '2020-02-29',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.67},
#            {'actual': True,
#             'depart_date': '2020-02-28',
#             'destination': 'KLF',
#             'distance': 131,
#             'duration': 90,
#             'found_at': '2020-02-13T18:34:56.379592',
#             'gate': 'Rusline',
#             'number_of_changes': 0,
#             'origin': 'MOW',
#             'return_date': '2020-03-01',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.73},
#            {'actual': True,
#             'depart_date': '2020-02-24',
#             'destination': 'MOW',
#             'distance': 131,
#             'duration': 90,
#             'found_at': '2020-02-12T13:00:39.707587',
#             'gate': 'Rusline',
#             'number_of_changes': 0,
#             'origin': 'KLF',
#             'return_date': '2020-03-06',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.73},
#            {'actual': True,
#             'depart_date': '2020-02-21',
#             'destination': 'GOT',
#             'distance': 529,
#             'duration': 145,
#             'found_at': '2020-02-12T16:00:49.935487',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-02-23',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.73},
#            {'actual': True,
#             'depart_date': '2020-03-23',
#             'destination': 'SSA',
#             'distance': 958,
#             'duration': 804,
#             'found_at': '2020-02-10T17:41:55.181479',
#             'gate': 'MyHolidays',
#             'number_of_changes': 2,
#             'origin': 'BHZ',
#             'return_date': '2020-03-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.81},
#            {'actual': True,
#             'depart_date': '2020-05-12',
#             'destination': 'BER',
#             'distance': 685,
#             'duration': 180,
#             'found_at': '2020-02-13T17:22:00.882405',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'BUD',
#             'return_date': '2020-05-13',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.82},
#            {'actual': True,
#             'depart_date': '2020-02-22',
#             'destination': 'TSE',
#             'distance': 407,
#             'duration': 135,
#             'found_at': '2020-02-10T07:23:29.720879',
#             'gate': 'Tickets.kz',
#             'number_of_changes': 0,
#             'origin': 'PWQ',
#             'return_date': '2020-02-29',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.94},
#            {'actual': True,
#             'depart_date': '2020-02-29',
#             'destination': 'PWQ',
#             'distance': 407,
#             'duration': 135,
#             'found_at': '2020-02-13T14:35:55.732092',
#             'gate': 'Tickets.kz',
#             'number_of_changes': 0,
#             'origin': 'TSE',
#             'return_date': '2020-03-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 21.94},
#            {'actual': True,
#             'depart_date': '2020-03-24',
#             'destination': 'VIE',
#             'distance': 61,
#             'duration': 225,
#             'found_at': '2020-02-13T14:51:39.868263',
#             'gate': 'KupiBilet.ru',
#             'number_of_changes': 0,
#             'origin': 'BTS',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.09},
#            {'actual': True,
#             'depart_date': '2020-03-11',
#             'destination': 'MIL',
#             'distance': 657,
#             'duration': 180,
#             'found_at': '2020-02-13T21:10:28.629726',
#             'gate': 'FlightNetwork',
#             'number_of_changes': 0,
#             'origin': 'VIE',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.21},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'KRK',
#             'distance': 1018,
#             'duration': 230,
#             'found_at': '2020-02-13T21:50:07.724846',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KHE',
#             'return_date': '2020-03-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-19',
#             'destination': 'BRI',
#             'distance': 383,
#             'duration': 135,
#             'found_at': '2020-02-13T12:20:43.366073',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'ROM',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-17',
#             'destination': 'PAR',
#             'distance': 708,
#             'duration': 195,
#             'found_at': '2020-02-13T19:52:48.399097',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-02-19',
#             'destination': 'DUB',
#             'distance': 1084,
#             'duration': 240,
#             'found_at': '2020-02-13T01:36:17.072671',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FRA',
#             'return_date': '2020-02-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'NAP',
#             'distance': 648,
#             'duration': 170,
#             'found_at': '2020-02-13T22:22:02.048633',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-17',
#             'destination': 'ROM',
#             'distance': 383,
#             'duration': 135,
#             'found_at': '2020-02-13T18:10:53.034257',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BRI',
#             'return_date': '2020-03-17',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'PMI',
#             'distance': 1305,
#             'duration': 295,
#             'found_at': '2020-02-13T21:00:06.345264',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'CGN',
#             'return_date': '2020-03-20',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-02-28',
#             'destination': 'KIR',
#             'distance': 1196,
#             'duration': 250,
#             'found_at': '2020-02-13T20:47:55.922020',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FRA',
#             'return_date': '2020-03-02',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-02-20',
#             'destination': 'CGN',
#             'distance': 610,
#             'duration': 175,
#             'found_at': '2020-02-13T23:27:07.874230',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-18',
#             'destination': 'BER',
#             'distance': 795,
#             'duration': 210,
#             'found_at': '2020-02-13T12:47:48.853515',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-22',
#             'destination': 'CPH',
#             'distance': 793,
#             'duration': 200,
#             'found_at': '2020-02-13T11:01:38.402663',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BRU',
#             'return_date': '2020-03-26',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-21',
#             'destination': 'ROM',
#             'distance': 687,
#             'duration': 180,
#             'found_at': '2020-02-13T10:52:26.989621',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MLA',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-04',
#             'destination': 'MIL',
#             'distance': 648,
#             'duration': 170,
#             'found_at': '2020-02-13T00:13:41.690344',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'NAP',
#             'return_date': '2020-03-17',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-02-25',
#             'destination': 'GDN',
#             'distance': 1232,
#             'duration': 260,
#             'found_at': '2020-02-13T18:31:34.592058',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'ODS',
#             'return_date': '2020-03-03',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-04',
#             'destination': 'BCN',
#             'distance': 1034,
#             'duration': 250,
#             'found_at': '2020-02-13T12:13:42.035046',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BRU',
#             'return_date': '2020-03-11',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-18',
#             'destination': 'ROM',
#             'distance': 994,
#             'duration': 230,
#             'found_at': '2020-02-13T16:40:47.227236',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FRA',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-10',
#             'destination': 'MLA',
#             'distance': 1105,
#             'duration': 235,
#             'found_at': '2020-02-13T08:43:24.974429',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'VCE',
#             'return_date': '2020-03-26',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-04',
#             'destination': 'MIL',
#             'distance': 838,
#             'duration': 200,
#             'found_at': '2020-02-13T12:59:36.408815',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BER',
#             'return_date': '2020-03-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-08',
#             'destination': 'KTW',
#             'distance': 1080,
#             'duration': 235,
#             'found_at': '2020-02-13T20:08:26.388221',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'KHE',
#             'return_date': '2020-03-11',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-12',
#             'destination': 'NAP',
#             'distance': 1146,
#             'duration': 250,
#             'found_at': '2020-02-13T17:25:30.987148',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FRA',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-02-26',
#             'destination': 'DUB',
#             'distance': 953,
#             'duration': 235,
#             'found_at': '2020-02-13T20:15:26.225885',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'CGN',
#             'return_date': '2020-02-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-25',
#             'destination': 'BRU',
#             'distance': 875,
#             'duration': 210,
#             'found_at': '2020-02-13T10:19:45.179839',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'PSA',
#             'return_date': '2020-03-30',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-14',
#             'destination': 'LON',
#             'distance': 930,
#             'duration': 245,
#             'found_at': '2020-02-13T14:28:54.349795',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-16',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-04-02',
#             'destination': 'WAW',
#             'distance': 1049,
#             'duration': 220,
#             'found_at': '2020-02-13T18:47:09.010802',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'EIN',
#             'return_date': '2020-04-05',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-30',
#             'destination': 'PMI',
#             'distance': 1210,
#             'duration': 260,
#             'found_at': '2020-02-13T12:09:37.863536',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FRA',
#             'return_date': '2020-03-31',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-19',
#             'destination': 'PMI',
#             'distance': 1383,
#             'duration': 275,
#             'found_at': '2020-02-13T22:01:26.682141',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DTM',
#             'return_date': '2020-03-30',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-17',
#             'destination': 'SOF',
#             'distance': 530,
#             'duration': 165,
#             'found_at': '2020-02-13T14:42:53.145088',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'ATH',
#             'return_date': '2020-03-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-14',
#             'destination': 'BOD',
#             'distance': 818,
#             'duration': 200,
#             'found_at': '2020-02-13T17:38:55.124516',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 22.24},
#            {'actual': True,
#             'depart_date': '2020-03-02',
#             'destination': 'LON',
#             'distance': 616,
#             'duration': 190,
# ...
#             'return_date': '2020-03-12',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.68},
#            {'actual': True,
#             'depart_date': '2020-02-19',
#             'destination': 'LUX',
#             'distance': 487,
#             'duration': 160,
#             'found_at': '2020-02-12T19:13:05.200585',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'LON',
#             'return_date': '2020-02-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.68},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'BCN',
#             'distance': 1185,
#             'duration': 285,
#             'found_at': '2020-02-12T19:16:37.464206',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'LON',
#             'return_date': '2020-03-07',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.68},
#            {'actual': True,
#             'depart_date': '2020-02-26',
#             'destination': 'ORK',
#             'distance': 556,
#             'duration': 170,
#             'found_at': '2020-02-12T16:31:06.247041',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'LON',
#             'return_date': '2020-02-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.68},
#            {'actual': True,
#             'depart_date': '2020-03-27',
#             'destination': 'LWO',
#             'distance': 1266,
#             'duration': 255,
#             'found_at': '2020-02-13T21:08:47.156574',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DUS',
#             'return_date': '2020-03-31',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.69},
#            {'actual': True,
#             'depart_date': '2020-03-17',
#             'destination': 'OPO',
#             'distance': 437,
#             'duration': 155,
#             'found_at': '2020-02-13T23:27:08.422545',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MAD',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.69},
#            {'actual': True,
#             'depart_date': '2020-03-25',
#             'destination': 'KRK',
#             'distance': 528,
#             'duration': 150,
#             'found_at': '2020-02-13T07:52:16.219579',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BER',
#             'return_date': '2020-03-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.69},
#            {'actual': True,
#             'depart_date': '2020-10-07',
#             'destination': 'SAO',
#             'distance': 872,
#             'duration': 715,
#             'found_at': '2020-02-13T23:31:14.570161',
#             'gate': 'Mytrip.com',
#             'number_of_changes': 1,
#             'origin': 'BSB',
#             'return_date': '2020-10-14',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.77},
#            {'actual': True,
#             'depart_date': '2020-02-14',
#             'destination': 'IZM',
#             'distance': 344,
#             'duration': 135,
#             'found_at': '2020-02-13T16:52:00.910408',
#             'gate': 'Pegasus Airlines',
#             'number_of_changes': 0,
#             'origin': 'IST',
#             'return_date': '2020-02-15',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.79},
#            {'actual': True,
#             'depart_date': '2020-05-06',
#             'destination': 'KUL',
#             'distance': 385,
#             'duration': 130,
#             'found_at': '2020-02-12T20:42:13.420015',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KBR',
#             'return_date': '2020-05-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.81},
#            {'actual': True,
#             'depart_date': '2020-03-21',
#             'destination': 'KTW',
#             'distance': 1118,
#             'duration': 245,
#             'found_at': '2020-02-10T19:07:28.795429',
#             'gate': 'MyHolidays',
#             'number_of_changes': 0,
#             'origin': 'OSL',
#             'return_date': '2020-03-22',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 26.82},
#            {'actual': True,
#             'depart_date': '2020-04-16',
#             'destination': 'MIL',
#             'distance': 818,
#             'duration': 200,
#             'found_at': '2020-02-10T13:26:22.147829',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BOD',
#             'return_date': '2020-04-23',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.03},
#            {'actual': True,
#             'depart_date': '2020-03-03',
#             'destination': 'BDS',
#             'distance': 1538,
#             'duration': 300,
#             'found_at': '2020-02-10T17:25:49.413725',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'EIN',
#             'return_date': '2020-03-31',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.03},
#            {'actual': True,
#             'depart_date': '2020-03-17',
#             'destination': 'LON',
#             'distance': 1045,
#             'duration': 255,
#             'found_at': '2020-02-12T14:42:34.137732',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'GOA',
#             'return_date': '2020-03-19',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.08},
#            {'actual': True,
#             'depart_date': '2020-02-15',
#             'destination': 'NUE',
#             'distance': 438,
#             'duration': 150,
#             'found_at': '2020-02-12T16:54:19.164852',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-02-28',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.08},
#            {'actual': True,
#             'depart_date': '2020-03-14',
#             'destination': 'LON',
#             'distance': 834,
#             'duration': 210,
#             'found_at': '2020-02-12T19:08:24.660156',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'FMM',
#             'return_date': '2020-03-15',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.08},
#            {'actual': True,
#             'depart_date': '2020-03-24',
#             'destination': 'LON',
#             'distance': 1431,
#             'duration': 310,
#             'found_at': '2020-02-12T14:26:35.477817',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'ALC',
#             'return_date': '2020-03-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.08},
#            {'actual': True,
#             'depart_date': '2020-03-04',
#             'destination': 'ADA',
#             'distance': 399,
#             'duration': 125,
#             'found_at': '2020-02-12T17:22:30.892613',
#             'gate': 'Kiwi.com',
#             'number_of_changes': 0,
#             'origin': 'AYT',
#             'return_date': '2020-03-11',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-03-27',
#             'destination': 'LON',
#             'distance': 403,
#             'duration': 145,
#             'found_at': '2020-02-11T21:29:54.995054',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DNR',
#             'return_date': '2020-03-30',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-02-27',
#             'destination': 'SOF',
#             'distance': 1305,
#             'duration': 275,
#             'found_at': '2020-02-11T16:19:48.075998',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'BER',
#             'return_date': '2020-03-04',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-03-16',
#             'destination': 'BCN',
#             'distance': 897,
#             'duration': 230,
#             'found_at': '2020-02-11T12:56:42.374992',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'OPO',
#             'return_date': '2020-03-18',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-03-22',
#             'destination': 'LON',
#             'distance': 508,
#             'duration': 165,
#             'found_at': '2020-02-11T21:59:31.805749',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DTM',
#             'return_date': '2020-03-24',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-03-19',
#             'destination': 'LPL',
#             'distance': 224,
#             'duration': 110,
#             'found_at': '2020-02-11T14:43:09.360628',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'DUB',
#             'return_date': '2020-03-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.09},
#            {'actual': True,
#             'depart_date': '2020-05-06',
#             'destination': 'OSL',
#             'distance': 844,
#             'duration': 190,
#             'found_at': '2020-02-13T06:14:24.768211',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'RIX',
#             'return_date': '2020-05-13',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.11},
#            {'actual': True,
#             'depart_date': '2020-03-05',
#             'destination': 'AES',
#             'distance': 1154,
#             'duration': 240,
#             'found_at': '2020-02-13T20:43:03.478437',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'GDN',
#             'return_date': '2020-03-09',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.11},
#            {'actual': True,
#             'depart_date': '2020-02-15',
#             'destination': 'CJU',
#             'distance': 183,
#             'duration': 100,
#             'found_at': '2020-02-11T09:15:26.201665',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'KWJ',
#             'return_date': '2020-02-18',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.25},
#            {'actual': True,
#             'depart_date': '2020-02-25',
#             'destination': 'KTW',
#             'distance': 809,
#             'duration': 200,
#             'found_at': '2020-02-13T09:27:53.189460',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'DTM',
#             'return_date': '2020-02-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.28},
#            {'actual': True,
#             'depart_date': '2020-02-20',
#             'destination': 'KYA',
#             'distance': 428,
#             'duration': 140,
#             'found_at': '2020-02-13T17:52:14.321084',
#             'gate': 'Pegasus Airlines',
#             'number_of_changes': 0,
#             'origin': 'IST',
#             'return_date': '2020-02-27',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.36},
#            {'actual': True,
#             'depart_date': '2020-03-26',
#             'destination': 'FAO',
#             'distance': 472,
#             'duration': 140,
#             'found_at': '2020-02-11T22:04:06.823488',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'OPO',
#             'return_date': '2020-03-29',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.36},
#            {'actual': True,
#             'depart_date': '2020-02-16',
#             'destination': 'ASR',
#             'distance': 578,
#             'duration': 165,
#             'found_at': '2020-02-13T16:43:01.035290',
#             'gate': 'Pegasus Airlines',
#             'number_of_changes': 0,
#             'origin': 'IST',
#             'return_date': '2020-02-21',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.36},
#            {'actual': True,
#             'depart_date': '2020-02-18',
#             'destination': 'BKI',
#             'distance': 607,
#             'duration': 150,
#             'found_at': '2020-02-11T05:57:31.290845',
#             'gate': 'Trip.com',
#             'number_of_changes': 0,
#             'origin': 'SBW',
#             'return_date': '2020-02-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.41},
#            {'actual': True,
#             'depart_date': '2020-03-18',
#             'destination': 'PMO',
#             'distance': 877,
#             'duration': 205,
#             'found_at': '2020-02-10T12:15:28.166627',
#             'gate': 'Ryanair',
#             'number_of_changes': 0,
#             'origin': 'MIL',
#             'return_date': '2020-03-18',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.47},
#            {'actual': True,
#             'depart_date': '2020-12-29',
#             'destination': 'SAO',
#             'distance': 865,
#             'duration': 560,
#             'found_at': '2020-02-13T20:53:08.494977',
#             'gate': 'Mytrip.com',
#             'number_of_changes': 1,
#             'origin': 'POA',
#             'return_date': '2021-01-05',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.49},
#            {'actual': True,
#             'depart_date': '2020-05-15',
#             'destination': 'ALA',
#             'distance': 460,
#             'duration': 130,
#             'found_at': '2020-02-13T11:30:57.603986',
#             'gate': 'Tickets.kz',
#             'number_of_changes': 0,
#             'origin': 'DMB',
#             'return_date': '2020-05-17',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.52},
#            {'actual': True,
#             'depart_date': '2020-05-10',
#             'destination': 'DMB',
#             'distance': 460,
#             'duration': 130,
#             'found_at': '2020-02-13T13:16:53.914740',
#             'gate': 'Tickets.kz',
#             'number_of_changes': 0,
#             'origin': 'ALA',
#             'return_date': '2020-05-12',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.52},
#            {'actual': True,
#             'depart_date': '2020-02-20',
#             'destination': 'AYT',
#             'distance': 463,
#             'duration': 150,
#             'found_at': '2020-02-13T15:05:34.666269',
#             'gate': 'Pegasus Airlines',
#             'number_of_changes': 0,
#             'origin': 'IST',
#             'return_date': '2020-02-25',
#             'show_to_affiliates': True,
#             'trip_class': 0,
#             'value': 27.52}],
#   'success': True}]

# %%
my_dict = pd.Series()
my_df = pd.DataFrame()

# Specify the file to write to
new_date=datetime.now().strftime ('%d-%b-%Y_%H:%M:%S')
file_name = new_date + ".csv"
output_path = os.path.join("output", file_name)
print(output_path)
# Out:
# output\13-Feb-2020_18:07:39.csv

# %%
# Specify the file to write to
output_path = os.path.join("output", "new.csv")

# Open the file using "write" mode. Specify the variable to hold the contents
with open(output_path, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
#     print(response_json)
    for x in response_json:
        print(x)
        my_dict = x
        
#         print(x)
#         my_dict= (x['name'],x['coord']['lon'],x['coord']['lat'],((x['main']['temp_max']-273.15)*9/5)+32,
#                   x['main']['humidity'],x['clouds']['all'],x['wind']['speed'],x['sys']['country'], local_time_fmt)
#         print(my_dict)
#         csvwriter.writerow(my_dict) # Export to cvs file

# read from created cvs file
# my_df = pd.read_csv(output_path, encoding="ISO-8859-1", low_memory=False)
my_df.head()
# Out:
# {'success': True, 'data': [{'value': 5.38, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-25', 'origin': 'PEN', 'number_of_changes': 0, 'gate': 'Trip.com', 'found_at': '2020-02-10T08:20:04.206070', 'duration': 80, 'distance': 130, 'destination': 'LGK', 'depart_date': '2020-03-23', 'actual': True}, {'value': 9.94, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-02-18', 'origin': 'GDN', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T19:14:37.704304', 'duration': 150, 'distance': 498, 'destination': 'STO', 'depart_date': '2020-02-14', 'actual': True}, {'value': 11.12, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-02', 'origin': 'INI', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T23:00:10.775230', 'duration': 155, 'distance': 647, 'destination': 'BTS', 'depart_date': '2020-02-28', 'actual': True}, {'value': 11.13, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-03', 'origin': 'DUB', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T18:47:15.607827', 'duration': 160, 'distance': 431, 'destination': 'LON', 'depart_date': '2020-03-03', 'actual': True}, {'value': 11.26, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-02-24', 'origin': 'TWU', 'number_of_changes': 0, 'gate': 'Trip.com', 'found_at': '2020-02-10T13:47:09.894735', 'duration': 115, 'distance': 274, 'destination': 'BKI', 'depart_date': '2020-02-19', 'actual': True}, {'value': 11.31, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-04', 'origin': 'STR', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-11T14:25:18.974116', 'duration': 150, 'distance': 547, 'destination': 'VIE', 'depart_date': '2020-03-03', 'actual': True}, {'value': 11.31, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-16', 'origin': 'CGN', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-11T19:50:28.824723', 'duration': 160, 'distance': 488, 'destination': 'LON', 'depart_date': '2020-03-12', 'actual': True}, {'value': 11.45, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-02-29', 'origin': 'STO', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T04:48:48.785436', 'duration': 150, 'distance': 498, 'destination': 'GDN', 'depart_date': '2020-02-25', 'actual': True}, {'value': 12.28, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-04-16', 'origin': 'AOR', 'number_of_changes': 0, 'gate': 'Trip.com', 'found_at': '2020-02-10T11:30:28.924817', 'duration': 145, 'distance': 409, 'destination': 'KUL', 'depart_date': '2020-04-10', 'actual': True}, {'value': 12.99, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-04-16', 'origin': 'KUL', 'number_of_changes': 0, 'gate': 'Trip.com', 'found_at': '2020-02-11T02:37:24.731069', 'duration': 135, 'distance': 409, 'destination': 'AOR', 'depart_date': '2020-04-14', 'actual': True}, {'value': 13.13, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-09-21', 'origin': 'POA', 'number_of_changes': 2, 'gate': 'MyHolidays', 'found_at': '2020-02-10T03:42:10.682175', 'duration': 930, 'distance': 533, 'destination': 'CWB', 'depart_date': '2020-09-18', 'actual': True}, {'value': 13.24, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-04', 'origin': 'BHX', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T19:55:54.016168', 'duration': 135, 'distance': 321, 'destination': 'DUB', 'depart_date': '2020-03-03', 'actual': True}, {'value': 13.24, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-03-11', 'origin': 'LON', 'number_of_changes': 0, 'gate': 'Ryanair', 'found_at': '2020-02-13T14:53:27.251871', 'duration': 165, 'distance': 470, 'destination': 'DUB', 'depart_date': '2020-03-11', 'actual': True}, {'value': 14.45, 'trip_class': 0, 'show_to_affiliates': True, 'return_date': '2020-05-06', 'origin': 'KUL', 'number_of_changes': 0, 'g ...
#    success                                               data
# 0     True  {'value': 5.38, 'trip_class': 0, 'show_to_affi...
# 1     True  {'value': 9.94, 'trip_class': 0, 'show_to_affi...
# 2     True  {'value': 11.12, 'trip_class': 0, 'show_to_aff...
# 3     True  {'value': 11.13, 'trip_class': 0, 'show_to_aff...
# 4     True  {'value': 11.26, 'trip_class': 0, 'show_to_aff...
