# %%
from bs4 import BeautifulSoup as bs
import requests 
import pymongo
import pandas as pd
import re
import os
import csv
import time
import json
import pprint
from datetime import datetime, timedelta

# %%
flight_url = "https://www.faredetective.com/farehistory/flights-from-Chicago-ORD-to-Amsterdam-AMS.html"
print("now processing: " + flight_url)

# new_date = corona_file[22:26]+"-"+corona_file[26:28]+"-"+corona_file[28:30]
# print(new_date)

response = requests.get(flight_url)
# time.sleep(10)
# Out:
# now processing: https://www.faredetective.com/farehistory/flights-from-Chicago-ORD-to-Amsterdam-AMS.html

# %%
print(response)
soup = bs(response.text, 'lxml')
print(soup)
# Out:
# <Response [200]>
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <title>Airfare History Charts for flights from Chicago to Amsterdam</title>
# <meta content="View how prices vary over time for flights from Chicago to Amsterdam and get the best prices." name="description"/>
# <meta content="index,follow" name="robots"/>
# <meta content="AC9F37E1C04E3C4C081C106F33A87E62" name="msvalidate.01"/>
# <link href="https://www.faredetective.com/assets/img/favicon2.ico?v=1" rel="shortcut icon"/>
# <!-- Bootstrap core CSS -->
# <link href="https://www.faredetective.com/assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://www.faredetective.com/assets/plugins/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://www.faredetective.com/assets/plugins/jquery-ui/jquery-ui.min.css" rel="stylesheet"/>
# ...

# %%
my_text = soup.find_all('td')

print("Lowest Price Found:" + str(my_text[0]))
print("Average Price Found:" + str(my_text[1]))
print("Cheapest month to travel:" + str(my_text[2]))

limit = 2

if response.status_code == 200:
    for index, d_fl in enumerate(my_text):
        print(d_fl.text)
        if index==limit:
            break
# Out:
# Lowest Price Found:<td class="text-right">$654</td>
# Average Price Found:<td class="text-right">$772</td>
# Cheapest month to travel:<td>March</td>
# $654
# $772
# March

# %%
my_text_headers = soup.find_all('th')
print(my_text_headers)
# Out:
# [<th>Lowest price found</th>, <th>Average price</th>, <th>Cheapest months to travel  </th>, <th>Route</th>, <th>Price</th>, <th></th>]
