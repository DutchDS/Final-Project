# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser

import requests 
import pymongo
import pandas as pd
import re

# %%
# executable_path = {'executable_path': 'chromedriver.exe'}
# browser = Browser('chrome', **executable_path, headless=True)

# %%
direct_flights_url = "https://www.flightsfrom.com/ATL"

# %%
# Retrieve page with the requests module
response = requests.get(direct_flights_url)
soup = bs(response.text, 'lxml')

# %%
direct_flights = soup.find_all('span', class_='hometoplist-first')

# Get first 15 direct flights
limit = 14

for index, d_fl in enumerate(direct_flights):
    print(index, d_fl.text)
    if index==limit:
        break
# Out:
# 0 La Guardia
# 1 Fort Lauderdale Hollywood International
# 2 Orlando International
# 3 Tampa International
# 4 Ronald Reagan Washington National
# 5 Newark Liberty International
# 6 Miami International
# 7 Chicago Ohare International
# 8 Dallas Fort Worth International
# 9 Philadelphia International
# 10 Los Angeles International
# 11 Charlotte Douglas International
# 12 Baltimore Washington International
# 13 Denver International
# 14 George Bush Intcntl Houston

# %%
get_flight_data_url = 'https://www.delta.com/flight-search-2/flexible-dates?cacheKeySuffix=a5fa83d9-86d4-438e-8aa6-684e9f5fe3ed'

# %%
# Retrieve page with the requests module
response = requests.get(direct_flights_url)
soup = bs(response.text, 'lxml')

# %%
flights_info = soup.find_all('span', class_='price-wrapper')

# attrs={'data-test-id':"listing-price-dollars"}
# <span class="full-bold no-wrap" data-test-id="listing-price-dollars">$290</span>

# %%
for fl_info in flights_info:
    print(fl_info)
    
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>
#     Direct (non-stop) flights from HartsfieldâJackson Atlanta (ATL) - FlightsFrom.com</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="f03606a309cb4f9f80b224845589c840" name="verification"/>
# <meta content="See all routes, airlines and scheduled direct (non-stop) flights from Hartsfield–Jackson Atlanta International Airport (ATL). Find detailed information for each departure 9 months ahead and explore all 244 destinations with our smart search tool and route map." name="description"/>
# <meta content="route,routes,map,destinations,airlines,flights,flight,flightnumber,flightnumbers,from,number,ATL,Hartsfield–Jackson Atlanta International Airport,airline,iata,aircraft,flighttime,schedule,timetable" name="keywords"/>
# ...
